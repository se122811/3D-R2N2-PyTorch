# %%
with open('prediction.obj','r') as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='prediction.obj' mode='r' encoding='UTF-8'>

# %%
with open('prediction.obj','r') as f:
    lines = f.readlines()
    for line in lines:
        print(line)
# Out:
# g
#
# # 24944 vertex
#
# v 0.033000 0.308000 0.242000
#
# v 0.033000 0.308000 0.252000
#
# v 0.033000 0.318000 0.242000
#
# v 0.033000 0.318000 0.252000
#
# v 0.043000 0.308000 0.242000
#
# v 0.043000 0.308000 0.252000
#
# v 0.043000 0.318000 0.242000
#
# v 0.043000 0.318000 0.252000
#
# v 0.033000 0.308000 0.253000
#
# v 0.033000 0.308000 0.263000
#
# v 0.033000 0.318000 0.253000
#
# v 0.033000 0.318000 0.263000
#
# v 0.043000 0.308000 0.253000
#
# v 0.043000 0.308000 0.263000
#
# v 0.043000 0.318000 0.253000
#
# v 0.043000 0.318000 0.263000
#
# v 0.033000 0.308000 0.264000
#
# v 0.033000 0.308000 0.274000
#
# v 0.033000 0.318000 0.264000
#
# v 0.033000 0.318000 0.274000
#
# v 0.043000 0.308000 0.264000
#
# v 0.043000 0.308000 0.274000
#
# v 0.043000 0.318000 0.264000
#
# v 0.043000 0.318000 0.274000
#
# v 0.033000 0.308000 0.275000
#
# v 0.033000 0.308000 0.285000
#
# v 0.033000 0.318000 0.275000
#
# v 0.033000 0.318000 0.285000
#
# v 0.043000 0.308000 0.275000
#
# ...

# %%
with open('/home/unist/hdd_ext/hdd_ext/hdd3000/ShapeNetCore.v1/02691156/1a04e3eab45ca15dd86060f189eb133/model.obj','r') as f:
    lines = f.readlines()
    for line in lines:
        print(line)
# Out:
# # Blender v2.71 (sub 0) OBJ File: 'blank.blend'
#
# # www.blender.org
#
# mtllib model.mtl
#
# o mesh41_mesh41-geometry
#
# o mesh40_mesh40-geometry
#
# o mesh39_mesh39-geometry
#
# v 0.0887421 -0.114009 0.0722861
#
# v 0.0884756 -0.117896 0.0724486
#
# v 0.0888633 -0.115971 0.0723381
#
# v 0.0881209 -0.112143 0.0722969
#
# v 0.0731323 -0.12046 -0.0608269
#
# v 0.0914827 -0.167417 0.0737626
#
# v 0.0730115 -0.118498 -0.060879
#
# v 0.0984815 -0.0654237 0.0694982
#
# v 0.0723904 -0.116632 -0.0608682
#
# v 0.0850231 -0.0626271 0.0709936
#
# v 0.0876056 -0.119651 0.0726107
#
# v 0.072745 -0.122384 -0.060716
#
# v 0.0777776 -0.168219 0.0754089
#
# v 0.071311 -0.11499 -0.060796
#
# v 0.0870416 -0.110501 0.0723691
#
# v 0.0750653 -0.168363 -0.0594403
#
# v 0.0815865 -0.0733199 -0.0634146
#
# v 0.0936328 -0.166804 0.0919644
#
# v 0.104501 -0.163073 0.0720785
#
# v 0.0690453 -0.0707138 -0.0620211
#
# v 0.100632 -0.0648099 0.0876999
#
# v 0.071875 -0.12414 -0.0605544
#
# ...

# %%
with open('/home/unist/hdd_ext/hdd_ext/hdd3000/ShapeNetCore.v1/02691156/1a04e3eab45ca15dd86060f189eb133/model.mtl','r') as f:
    lines = f.readlines()
    for line in lines:
        print(line)
# Out:
# # Blender MTL File: 'blank.blend'
#
# # Material Count: 11
#
#
#
# newmtl material_0_24
#
# Ns 96.078431
#
# Ka 0.000000 0.000000 0.000000
#
# Kd 0.000000 0.313726 0.000000
#
# Ks 0.500000 0.500000 0.500000
#
# Ni -1.000000
#
# d 1.000000
#
# illum 2
#
#
#
# newmtl material_10_24
#
# Ns 96.078431
#
# Ka 0.000000 0.000000 0.000000
#
# Kd 0.109804 0.109804 0.109804
#
# Ks 0.500000 0.500000 0.500000
#
# Ni -1.000000
#
# d 1.000000
#
# illum 2
#
#
#
# newmtl material_1_24
#
# Ns 96.078431
#
# Ka 0.000000 0.000000 0.000000
#
# Kd 0.800000 0.800000 0.800000
#
# Ks 0.500000 0.500000 0.500000
#
# Ni -1.000000
#
# d 1.000000
#
# illum 2
#
#
#
# newmtl material_2_24
#
# Ns 96.078431
#
# Ka 0.000000 0.000000 0.000000
#
# Kd 0.501961 0.257255 0.141177
#
# Ks 0.500000 0.500000 0.500000
#
# Ni -1.000000
#
# d 1.000000
#
# illum 2
#
#
#
# newmtl material_3_24
#
# Ns 96.078431
#
# Ka 0.000000 0.000000 0.000000
#
# Kd 0.800000 0.800000 0.000000
#
# Ks 0.500000 0.500000 0.500000
#
# Ni -1.000000
#
# ...
